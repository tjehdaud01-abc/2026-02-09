# %% [markdown]
# # 📘 파이썬 기초: 03. 선택 구조

# %% [markdown]
# ## 1. 비교 연산자 (Comparison Operators)
# * **개념**: 두 값의 크기를 비교하여 참(`True`) 또는 거짓(`False`)을 결과로 반환하는 연산자입니다.
# * **주요 연산자**:
#     * `==` : 같다
#     * `!=` : 다르다
#     * `>` / `<` : 크다 / 작다
#     * `>=` / `<=` : 크거나 같다 / 작거나 같다

# %%
# 무작위로 정수 두개(a,b)를 생성한 다음에 a나누기b의 몫과 나머지를 출력
# a 는 10~50 사이 숫자 b 2~9사이 숫자
# a 나누기 b의 몫과 나머지
# my_quotient 몫을 예측한 값을 입력
# my_remainder 나머지를 예측한 값을 입력
# 실제 값과 예측값을 비교해서 출력 : True, False

# %%
import random
a = random.randint(10, 50)
b = random.randint(2, 9)

your_quoitent = a // b
your_remainder = a % b

my_quoitent = int(input('A 숫자를 입력하세요 '))
my_remainder = int(input('B 숫자를 입력하세요 '))

print(f'A 입력 결과 : {my_quoitent} || B 입력 결과 : {my_remainder}')
print(f'나눈 결과 {your_quoitent } || 나머지 {your_remainder}')
print(f'나눈 결과 {your_quoitent == my_quoitent} || 나머지 {your_remainder == my_remainder }')

# %%
print(f' [a]')

# %%
import random

dice1 = random.randint(1,6)
dice2 = random.randint(1,6)

if dice1 > dice2:
  print(f'1번 주사위 승리 : {dice1}')
elif dice1 < dice2:
  print(f'2번 주사위 승리 : {dice2}')
else :
  print('무승부')

# %%
num = int(input('숫자 입력'))
if num % 2 == 0:
  print(f'{num}은 짝수')
else:
  print(f'{num}은 홀수')

# %%
won = 10000
price = int(input('가격 입력'))
if price >= won:
  print(f'할인 가격 {price * 0.95}원 지불')
else :
  print(f'가격 {price}원 지불')

# %% [markdown]
# ## 2. 선택 구조 (Selection Structure)
# * **개념**: 조건식의 결과에 따라 실행할 문장을 결정하는 구조입니다.
# * **if 문**: 조건이 참일 때만 실행할 문장을 작성합니다.
# * **if-else 문**: 조건이 참일 때와 거짓일 때 실행할 문장을 각각 나누어 작성합니다.
# * **if-elif-else 문**: 여러 개의 조건을 순차적으로 체크해야 할 때 사용합니다.
# * **주의 사항**:
#     * 조건문 끝에는 반드시 **콜론(:)**을 붙여야 합니다.
#     * 실행할 문장은 반드시 **들여쓰기(Indentation)**를 해야 합니다.

# %%
try1 = int(input('첫번째 숫자를 입력하세요'))
try2 = int(input('두번째 숫자를 입력하세요'))
try3 = int(input('세번째 숫자를 입력하세요'))

if try1 > try2:
    if try1 > try3:
      print(f'선수기록: {try1}')
    else:
      print(f'선수기록: {try3}')
else:
    if try2 > try3:
      print(f'선수기록: {try2}')
    else:
      print(f'선수기록: {try3}')

# %%
## 회원 등급을 입력 받음 (우수 또는 일반)
## 구매액을 입력 받음
## 기본 배송비 6천원
## 우수 고객이거나 2만원 이상 구매자 배송비 무료
## 결제 금액 출력 (배송비 포함해서)
## 변수 delivery_fee,level,price

# %%
delivery_leverl = input('회원 등급을 입력하세요 (우수,일반)')
delivery_fee = 2000
delivery_price = int(input('결제금액을 입력하세요'))

if delivery_leverl == '우수' or delivery_price >= 20000:
  delivery_fee = 0
  print(f' 결제금액 {delivery_price}원')
else:
  print(f' 결제금액 {delivery_price + delivery_fee}원')
# Out:
# 회원 등급을 입력하세요 (우수,일반)일반
# 결제금액을 입력하세요3000
#  결제금액 9000원

# %% [markdown]
# ## 3. 논리 연산자 (Logical Operators)
# * **개념**: 여러 개의 조건식을 조합하여 하나의 결과를 얻을 때 사용합니다.
# * **종류**:
#     * `and` : 두 조건이 모두 참일 때만 참
#     * `or` : 두 조건 중 하나만 참이어도 참
#     * `not` : 참을 거짓으로, 거짓을 참으로 반전

# %%
a = 25
print(a>=8 and a<60)

a = 70
print(a<8 or a>=60)

a = 20
print(not a ==20)

# %%
# 정수 인자 받아서 3의 배수 이고 5의 배수 인자 출력

# %%
a = int(input('정수를 입력하세요: '))

if a % 3 == 0 and a % 5 == 0:
    print(f'{a}는 3과 5의 배수가 맞습니다')
else:
    print(f'{a}는 3과 5의 배수가 아닙니다')

# %%
# 연도를 입력 받아서 윤년인지 평년인지 판별
# 윤년(2월29일)은 4년에 한번, 400년에 한번 윤년이고, 그런데 100째 해는 윤년이 아님

# %%
year = int(input('연도를 입력하세요: '))

if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
    print(f'{year}년은 윤년입니다')
else:
    print(f'{year}년은 평년입니다')

# %% [markdown]
# ## 4. 함수 (Function)
# * **개념**: 특정 작업을 수행하는 명령어들의 묶음입니다.
# * **라이브러리 활용**: `import` 키워드를 사용하여 외부 도구(라이브러리)를 불러올 수 있습니다.
# * **랜덤 함수**: `random.randint(start, end)`는 지정한 범위 내의 정수 중 하나를 무작위로 반환합니다.

# %%
import random

user = input('가위, 바위, 보 :')
com_rand = random.randint(1,3)

if com_rand == 1:
  computer = '가위'
elif com_rand == 2:
  computer = '바위'
else:
  computer = '보'

print(f'나 : {user} | 컴퓨터 : {computer}')

#승부 겨루기
if user == computer:
  print('무승부')
elif user == '바위':
  print("플레이어 승리")
elif user == '가위':
  print("플레이어 승리")
elif user == '보':
  print("플레이어 승리")
elif computer == "보":
  print("컴퓨터 승리")
elif computer == "바위":
  print("컴퓨터 승리")
elif computer == "가위":
  print("컴퓨터 승리")

# %%
# 함수이름 add, sub, mul, div
# a,b 두개의 정수 입력 받기
# 각 함수 호출해서 출력
# a+b = 덧셈함수 호출

# %%
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    return a / b   # 나눗셈


# 입력 받기
a = int(input("첫 번째 정수 입력: "))
b = int(input("두 번째 정수 입력: "))


# 함수 호출 & 출력
print(f"{a} + {b} = {add(a, b)}")
print(f"{a} - {b} = {sub(a, b)}")
print(f"{a} * {b} = {mul(a, b)}")
print(f"{a} / {b} = {div(a, b)}")

# %%
# div 함수에서 몫 나머지 반환
# 변수 몫
# 몫 나머지 출력

# %%
div(a,b)

quotient = a // b
remainder = a % b

a = int(input('함수 입력'))
b = int(input('함수 입력'))

print(f'몫 : {quotient} 나머지 : {remainder}')

# %% [markdown]
# ## 5. [실습 예제]
#
# ### 🌡️ 온도 변환기 (온도 종류 통합형)
# 1. **입력**: 사용자로부터 온도 종류(섭씨 또는 화씨)와 온도 값을 입력받습니다.
# 2. **판단 및 계산**:
#     * `if kind == '섭씨':` 이면 화씨 공식(`temp * 1.8 + 32`)으로 계산합니다.
#     * `else:` 이면 화씨로 간주하고 섭씨 공식(`(temp - 32) / 1.8`)으로 계산합니다.
# 3. **출력**: 변환된 온도 결과를 화면에 표시합니다.

# %%
caisius = int(input('섭씨온도를 입력하세요'))

# %%
caisius*(9/5)+ 32

# %%
fahranheit = int(input('화씨온도를 입력하세요'))

# %%
(fahranheit-32)*5/9

# %%
kind = input("확인할 온도 종류 입력(화씨, 섭씨) : ")
temp = int(input('현재 온도 입력: '))

if kind == "섭씨":
  farenheit = temp * 9 / 5 + 32
  print(f'출력 결과 온도는 {farenheit} {kind}를 입력함')
elif kind == "화씨":
  celsius = (temp - 32) * 5 / 9
  print(f'출력 결과 온도는 {celsius} {kind}를 입력함')
else:
  print('입력값이 잘못됨')

# %% [markdown]
# ### 📐 두 도형의 넓이 비교하기
# 1. **계산**: 사각형(가로×세로)과 삼각형(밑변×높이/2)의 정보를 각각 입력받아 넓이를 구합니다.
# 2. **비교**:
#     * `if 넓이1 > 넓이2:` 첫 번째 도형이 더 넓다고 출력합니다.
#     * `elif 넓이1 < 넓이2:` 두 번째 도형이 더 넓다고 출력합니다.
#     * `else:` 두 도형의 넓이가 같다고 출력합니다.

# %%
#사각형, 삼각형 , 원 함수 만들기
import math
def square(x,y):
  return x*y

def triangle(x,y):
  return x*y / 2

def circle (x):
  return math.pi * x**2

shape_type1 = input('도형1의 종류(사각형,삼각형,원): ')
shape_type2 = input('도형2의 종류(사각형,삼각형,원): ')

# 도형 1 가로 세로 입력 받기 / 함수에 반환 넓이 구하기

if shape_type1 == '사각형':
  H_square = int(input('사각형 가로:'))
  W_square = int(input('사각형 세로:'))
  area1 = square(H_square,W_square)
  print(f'사각형의 넓이는:{area1}')

elif shape_type1 == '삼각형':
  B_triangle = int(input('삼각형 밑변:'))
  H_triangle = int(input('삼각형 높이:'))
  area1 = triangle(B_triangle,H_triangle)
  print(f'심각형의 넓이는:{area1}')

else:
  R_circle = int(input('원의 반지름:'))
  area1 = circle(R_circle)
  print(f'원의 넓이는:{area1}')

# 도형 2 가로 세로 입력 받기 / 함수에 반환 넓이 구하기

if shape_type2 == '사각형':
  H_square = int(input('사각형 가로:'))
  W_square = int(input('사각형 세로:'))
  area2 = square(H_square,W_square)
  print(f'사각형의 넓이는:{area2}')

elif shape_type2 == '삼각형':
  B_triangle = int(input('삼각형 밑변:'))
  H_triangle = int(input('삼각형 높이:'))
  area2 = triangle(B_triangle,H_triangle)
  print(f'심각형의 넓이는:{area2}')

else:
  R_circle = int(input('원의 반지름:'))
  area2 = circle(R_circle)
  print(f'원의 넓이는:{area2}')

#넓이 비교

if area1 == area2:
  print('두 도형의 넓이가 같습니다')
elif area1 > area2:
  print(f'첫 번째 도형이 {area1-area2}만큼 더 큽니다')
else:
  print(f'두 번째 도형이{area2-area1} 더 큽니다')김지수  [오후 4:30]
import math

def square(width, height): #사각형
  return width * height
def triangle(width, height): #삼각형
  return width * height / 2
def circle(radius): #원
  return math.pi * radius * radius

#1번째 선택지
sharp_type1 = input("1번 도형을 입력하세요(사각형/삼각형/원)")

if sharp_type1 == "삼각형":
  width = int(input("밑변 입력"))
  height = int(input("높이 입력"))
  area1 = triangle(width, height)
elif sharp_type1 == "사각형":
  width = int(input("가로 입력"))
  height = int(input("세로 입력"))
  area1 = square(width, height)
elif sharp_type1 == "원":
  radius = int(input("반지름 입력"))
  area1 = circle(radius)
else:
  print("잘못된 입력입니다.")
  area1 = None

#2번째 선택지
sharp_type2 = input("2번 도형을 입력하세요(사각형/삼각형/원)")

if sharp_type2 == "삼각형":
  width = int(input("밑변 입력"))
  height = int(input("높이 입력"))
  area2 = triangle(width, height)
elif sharp_type2 == "사각형":
  width = int(input("가로 입력"))
  height = int(input("세로 입력"))
  area2 = square(width, height)
elif sharp_type2 == "원":
  radius = int(input("반지름 입력"))
  area2 = circle(radius)
else:
  print("잘못된 입력입니다.")
  area2 = None

# 비교 및 출력
if area1 is not None and area2 is not None:
  if area1 > area2:
    print(f'{sharp_type1}이(가) {sharp_type2}보다 {area1-area2} 만큼 더 넓음')
  elif area1 < area2:
    print(f'{sharp_type2}이(가) {sharp_type1}보다 {area2-area1} 만큼 더 넓음')
  else:
    print("두 도형의 길이가 똑같음")
